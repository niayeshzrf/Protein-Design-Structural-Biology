# %%
from matplotlib import pyplot as plt
from mpl_toolkits.axisartist.axislines import SubplotZero
import numpy as np

# %%
Step1 = "/Users/Nia/Documents/PhD/Iminium_Catalyst/Final/Energies/Goodvibes_Step1.csv"
Step2 = "/Users/Nia/Documents/PhD/Iminium_Catalyst/Final/Energies/Goodvibes_Step2.csv"
Step3 = "/Users/Nia/Documents/PhD/Iminium_Catalyst/Final/Energies/Goodvibes_Step3.csv"
Step4 = "/Users/Nia/Documents/PhD/Iminium_Catalyst/Final/Energies/Goodvibes_Step4.csv"
Step5 = "/Users/Nia/Documents/PhD/Iminium_Catalyst/Final/Energies/Goodvibes_Step5.csv"
Step6 = "/Users/Nia/Documents/PhD/Iminium_Catalyst/Final/Energies/Goodvibes_Step6.csv"

Deprot_ECN =  "/Users/Nia/Documents/PhD/Iminium_Catalyst/Final/Energies/Goodvibes_Deprot_ECN.csv"
Deprot_ECN_ASP =  "/Users/Nia/Documents/PhD/Iminium_Catalyst/Final/Energies/Goodvibes_Deprot_ECN_ASP.csv"

# %%
def read_en(energy_file):
    Species = []
    Energies = []
    with open(energy_file,'r') as infile:
        lines = infile.readlines()
        for i in range(len(lines)):
            l = lines[i].split(',')
            if len(l)==9 and l[1] == '0.00':
                l2 = lines[i+1].split(',')
                l3 = lines[i+2].split(',')
                Species.append(l[0][2:])
                Species.append(l2[0][2:])
                Species.append(l3[0][2:])
                Energies.append(float(l[-3]))
                Energies.append(float(l2[-3]))
                Energies.append(float(l3[-3]))
    return [Species,Energies]

# %%
def plot_energies(Spe_En):
    Species = Spe_En[0]
    Energies = Spe_En[1]
    
    fig, ax = plt.subplots(figsize=(10,10))
    ax.tick_params(axis="y",direction="in")
    ax.tick_params(axis="x",direction="in")
    
    plt.hlines(Energies[0],0,1,colors='black',linewidth=5)
    plt.hlines(Energies[1],2,3,colors='black',linewidth=5)
    plt.hlines(Energies[2],4,5,colors='black',linewidth=5)
    
    plt.plot([1,2],[Energies[0],Energies[1]],c='black',linewidth=3)
    plt.plot([3,4],[Energies[1],Energies[2]],c='black',linewidth=3)
    
    plt.xticks([0.5,2.5,4.5],[Species[0],Species[1],Species[2]],fontname='Arial',fontsize=30)
    plt.yticks(fontname='Arial',fontsize=30)
    plt.ylabel('relative G (kcal/mol)',fontname='Arial',fontsize=30)

    plt.show()

# %%
Deprot_ECN_energies = read_en(Deprot_ECN)
Deprot_ECN_energies_ASP = read_en(Deprot_ECN_ASP)

Step1_energies = read_en(Step1)
Step2_energies = read_en(Step2)
Step3_energies = read_en(Step3)
Step4_energies = read_en(Step4)
Step5_energies = read_en(Step5)

plot_energies(Deprot_ECN_energies)

plot_energies(Deprot_ECN_energies_ASP)

plot_energies(Step1_energies)
plot_energies(Step2_energies)
plot_energies(Step3_energies)
plot_energies(Step4_energies)
plot_energies(Step5_energies)

# %%
Step1_energies = read_en(Step1)[1]
Step2_energies = read_en(Step2)[1]
Step3_energies = read_en(Step3)[1]
Step4_energies = read_en(Step4)[1]
Step5_energies = read_en(Step5)[1]
#Step6_energies = read_en(Step6)[1]
#Step7_energies = read_en(Step7)[1]

fig, ax = plt.subplots(figsize=(60,30))
ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

plt.hlines(Step1_energies[0],0,1,colors='black',linewidth=10)
plt.hlines(Step1_energies[1],2,3,colors='black',linewidth=10)
plt.hlines(Step1_energies[2],4,5,colors='black',linewidth=10)
    
plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='black',linewidth=10)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='black',linewidth=10)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='black',linewidth=10)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)

plt.hlines(Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)
plt.hlines(Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='black',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)

plt.hlines(Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='black',linewidth=10)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)

#plt.hlines(Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)
#plt.hlines(Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='black',linewidth=10)
#plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='black',linewidth=10)

#plt.hlines(Step7_energies[0]+Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='black',linewidth=10)
#plt.hlines(Step7_energies[1]+Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],26,27,colors='black',linewidth=10)
#plt.hlines(Step7_energies[2]+Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],28,29,colors='black',linewidth=10)


plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],'--',c='black',linewidth=6)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([13,14],[Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([15,16],[Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([17,18],[Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

#plt.plot([21,22],[Step6_energies[0]+Step5_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
#plt.plot([23,24],[Step6_energies[1]+Step5_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

#plt.plot([25,26],[Step7_energies[0]+Step6_energies[2]+Step5_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step7_energies[1]+Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
#plt.plot([27,28],[Step7_energies[1]+Step6_energies[2]+Step5_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step7_energies[2]+Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.xticks([0.5,2.5,4.5,6.5,8.5,10.5,12.5,14.5,16.5,18.5,20.5,22.5,24.5],
           ['R','TS1','I1','TS2','I2','TS3','I3','TS4','I4','TS5','I5','TS6','P']
          ,fontsize=80,fontname='Arial')

plt.yticks(fontname='Arial',fontsize=80)

plt.ylabel('relative Gibbs Energy (kcal/mol)',fontname='Arial',fontsize=80)

plt.show()

# %%
def read_en_e(energy_file):
    Species = []
    Energies = []
    with open(energy_file,'r') as infile:
        lines = infile.readlines()
        for i in range(len(lines)):
            l = lines[i].split(',')
            if len(l)==9 and l[1] == '0.00':
                l2 = lines[i+1].split(',')
                l3 = lines[i+2].split(',')
                Species.append(l[0][2:])
                Species.append(l2[0][2:])
                Species.append(l3[0][2:])
                Energies.append(float(l[1]))
                Energies.append(float(l2[1]))
                Energies.append(float(l3[1]))
    return [Species,Energies]

# %%
def plot_energies_e(Spe_En,title):
    Species = Spe_En[0]
    Energies = Spe_En[1]

    fig, ax = plt.subplots(figsize=(10,10))
    ax.tick_params(axis="y",direction="in")
    ax.tick_params(axis="x",direction="in")
    ax.tick_params(axis='both', which='major', labelsize=50, width=2.5, length=10,pad=30)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    plt.grid(axis='y', color='silver', linewidth=0.8)

    plt.hlines(Energies[0],0,1,colors='black',linewidth=3)
    plt.hlines(Energies[1],2,3,colors='black',linewidth=12)
    plt.hlines(Energies[2],4,5,colors='black',linewidth=3)
    
    plt.plot([1,2],[Energies[0],Energies[1]],c='black',linewidth=3)
    plt.plot([3,4],[Energies[1],Energies[2]],c='black',linewidth=3)
    
    #plt.xticks([0.5,2.5,4.5],[Species[0],Species[1],Species[2]],fontname='Arial',fontsize=30)
    plt.xticks([])
    #plt.ylim(-0.2,14)
    #plt.yticks(np.arange(0,15,2),fontname='Arial',fontsize=30)
    plt.xlim(0,5)
    
    #plt.ylabel('free energy (kcal/mol)',fontname='Arial',fontsize=30)

    #plt.show()
    plt.savefig(title + '.png', transparent=True, dpi=300)

# %%
Deprot_ECN_energies_e = read_en_e(Deprot_ECN)
Deprot_ECN_energies_e_ASP = read_en_e(Deprot_ECN_ASP)

Step1_energies_e = read_en_e(Step1)
Step2_energies_e = read_en_e(Step2)
Step3_energies_e = read_en_e(Step3)
Step4_energies_e = read_en_e(Step4)
Step5_energies_e = read_en_e(Step5)
Step6_energies_e = read_en_e(Step6)




plot_energies_e(Deprot_ECN_energies_e,"ECN_HIS")
plot_energies_e(Deprot_ECN_energies_e_ASP,"ECN_ASP")

plot_energies_e(Step1_energies_e,"STEP1")
plot_energies_e(Step2_energies_e,"STEP2")
plot_energies_e(Step3_energies_e,"STEP3")
plot_energies_e(Step3_energies_e,"STEP4")
plot_energies_e(Step5_energies_e,"STEP5")
plot_energies_e(Step6_energies_e,"STEP6")

# %%
Step1_energies = read_en_e(Step1)[1]
Step2_energies = read_en_e(Step2)[1]
Step3_energies = read_en_e(Step3)[1]
Step4_energies = read_en_e(Step4)[1]
Step5_energies = read_en(Step5)[1]
Step6_energies = read_en(Step6)[1]

fig, ax = plt.subplots(figsize=(60,30))
ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

plt.hlines(Step1_energies[0],0,1,colors='black',linewidth=10)
plt.hlines(Step1_energies[1],2,3,colors='black',linewidth=10)
plt.hlines(Step1_energies[2],4,5,colors='black',linewidth=10)
    
plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='black',linewidth=10)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='black',linewidth=10)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='black',linewidth=10)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)

plt.hlines(Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)
plt.hlines(Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='black',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)

plt.hlines(Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='black',linewidth=10)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)

plt.hlines(Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)
plt.hlines(Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='black',linewidth=10)
plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='black',linewidth=10)




plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],'--',c='black',linewidth=6)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([13,14],[Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([15,16],[Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([17,18],[Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([21,22],[Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([23,24],[Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)


#plt.xticks([0.5,2.5,4.5,6.5,8.5,10.5,12.5,14.5,16.5,18.5,20.5,22.5,24.5],
  #         ['R','TS1','I1','TS2','I2','TS3','I3','TS4','I4','TS5','I5','TS6','P']
  #        ,fontsize=80,fontname='Arial')

#plt.yticks(fontname='Arial',fontsize=80)

#plt.ylabel('relative electronic energy (kcal/mol)',fontname='Arial',fontsize=80)

plt.show()

# %%
def arrowed_spines(fig, ax):

    xmin, xmax = ax.get_xlim() 
    ymin, ymax = ax.get_ylim()

    # removing the default axis on all sides:
    for side in ['bottom','right','top','left']:
        ax.spines[side].set_visible(False)

    # removing the axis ticks
    plt.xticks([]) # labels 
    plt.yticks([])
    ax.xaxis.set_ticks_position('none') # tick markers
    ax.yaxis.set_ticks_position('none')

    # get width and height of axes object to compute 
    # matching arrowhead length and width
    dps = fig.dpi_scale_trans.inverted()
    bbox = ax.get_window_extent().transformed(dps)
    width, height = bbox.width, bbox.height

    # manual arrowhead width and length
    hw = 1./20.*(ymax-ymin) 
    hl = 1./20.*(xmax-xmin)
    lw = 1. # axis line width
    ohg = 0.3 # arrow overhang

    # compute matching arrowhead length and width
    yhw = hw/(ymax-ymin)*(xmax-xmin)* height/width 
    yhl = hl/(xmax-xmin)*(ymax-ymin)* width/height

    # draw x and y axis
    ax.arrow(xmin, 0, xmax-xmin, 0., fc='k', ec='k', lw = lw, 
             head_width=hw, head_length=hl, overhang = ohg, 
             length_includes_head= True, clip_on = False) 

    ax.arrow(0, ymin, 0., ymax-ymin, fc='k', ec='k', lw = lw, 
             head_width=yhw, head_length=yhl, overhang = ohg, 
             length_includes_head= True, clip_on = False)

# %%
Step1_energies = read_en_e(Step1)[1]
Step2_energies = read_en_e(Step2)[1]
Step3_energies = read_en_e(Step3)[1]
Step4_energies = read_en_e(Step4)[1]
Step5_energies = read_en(Step5)[1]
#Step6_energies = read_en(Step6)[1]

fig, ax = plt.subplots(figsize=(60,30))

plt.hlines(Step1_energies[0],0,1,colors='black',linewidth=10)
plt.hlines(Step1_energies[1],2,3,colors='black',linewidth=10)
plt.hlines(Step1_energies[2],4,5,colors='black',linewidth=10)
    
plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='black',linewidth=10)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='black',linewidth=10)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='black',linewidth=10)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)

plt.hlines(Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)
plt.hlines(Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='black',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)

plt.hlines(Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='black',linewidth=10)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)

#plt.hlines(Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)
#plt.hlines(Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='black',linewidth=10)
#plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='black',linewidth=10)

plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],'--',c='black',linewidth=6)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([13,14],[Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([15,16],[Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.plot([17,18],[Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

#plt.plot([21,22],[Step6_energies[0]+Step5_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)
#plt.plot([23,24],[Step6_energies[1]+Step5_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],'--',c='black',linewidth=6)

plt.xticks([])

plt.yticks([])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

[x.set_linewidth(5) for x in ax.spines.values()]

ax.arrow(-1, -60 ,25, 0., fc='k', ec='k', lw = 5, 
             head_width=2, head_length=0.3, overhang = 2, 
             length_includes_head= True, clip_on = False) 
ax.arrow(-1, -60, 0., 80, fc='k', ec='k', lw = 5, 
             head_width=0.25, head_length=2, overhang = 2, 
             length_includes_head= True, clip_on = False) 
#plt.show()

plt.savefig('Energies.png', transparent=True, dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

def arrowed_spines(fig, ax):

    xmin, xmax = ax.get_xlim() 
    ymin, ymax = ax.get_ylim()

    # removing the default axis on all sides:
    for side in ['bottom','right','top','left']:
        ax.spines[side].set_visible(False)

    # removing the axis ticks
    plt.xticks([]) # labels 
    plt.yticks([])
    ax.xaxis.set_ticks_position('none') # tick markers
    ax.yaxis.set_ticks_position('none')

    # get width and height of axes object to compute 
    # matching arrowhead length and width
    dps = fig.dpi_scale_trans.inverted()
    bbox = ax.get_window_extent().transformed(dps)
    width, height = bbox.width, bbox.height

    # manual arrowhead width and length
    hw = 1./20.*(ymax-ymin) 
    hl = 1./20.*(xmax-xmin)
    lw = 1. # axis line width
    ohg = 0.3 # arrow overhang

    # compute matching arrowhead length and width
    yhw = hw/(ymax-ymin)*(xmax-xmin)* height/width 
    yhl = hl/(xmax-xmin)*(ymax-ymin)* width/height

    # draw x and y axis
    ax.arrow(xmin, 0, xmax-xmin, 0., fc='k', ec='k', lw = lw, 
             head_width=hw, head_length=hl, overhang = ohg, 
             length_includes_head= True, clip_on = False) 

    ax.arrow(0, ymin, 0., ymax-ymin, fc='k', ec='k', lw = lw, 
             head_width=yhw, head_length=yhl, overhang = ohg, 
             length_includes_head= True, clip_on = False)
    print(hw,yhw,hl,yhl)

# plot
x = np.arange(-2., 10.0, 0.01)
plt.plot(x, x**2)
fig = plt.gcf()
fig.set_facecolor('white') 
ax = plt.gca()

arrowed_spines(fig, ax)

plt.show()
# Out:
# 5.489005500000012 0.49139661290322634 0.6594500000000006 7.366197857142872

# %%
### Energy Plot without labels

Step1_energies = read_en_e(Step1)[1]
Step2_energies = read_en_e(Step2)[1]
Step3_energies = read_en_e(Step3)[1]
Step4_energies = read_en_e(Step4)[1]
Step5_energies = read_en(Step5)[1]
Step6_energies = read_en(Step6)[1]

fig, ax = plt.subplots(figsize=(30,30))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)



plt.hlines(Step1_energies[0],0,1,colors='black',linewidth=10)
plt.hlines(Step1_energies[1],2,3,colors='black',linewidth=10)
plt.hlines(Step1_energies[2],4,5,colors='black',linewidth=10)
    
plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='black',linewidth=10)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='black',linewidth=10)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='black',linewidth=10)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)

plt.hlines(Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)
plt.hlines(Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='black',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)

plt.hlines(Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='black',linewidth=10)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)

plt.hlines(Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)
plt.hlines(Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='black',linewidth=10)
plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='black',linewidth=10)




plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],c='black',linewidth=6)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],c='black',linewidth=6)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],c='black',linewidth=6)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)

plt.plot([13,14],[Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)
plt.plot([15,16],[Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)

plt.plot([17,18],[Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)

plt.plot([21,22],[Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)
plt.plot([23,24],[Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=6)



plt.axis('off')
plt.tick_params(axis='both', left=False, top=False, right=False, bottom=False, labelleft=False, labeltop=False, labelright=False, labelbottom=False)
plt.savefig('EnergyPlot.png', dpi=300, bbox_inches='tight', pad_inches=0.0,transparent=True)

# %%
### Energy Plot example enzyme

### Energy Plot without labels

Step1_energies = read_en_e(Step1)[1]
Step2_energies = read_en_e(Step2)[1]
Step3_energies = read_en_e(Step3)[1]
Step4_energies = read_en_e(Step4)[1]
Step5_energies = read_en(Step5)[1]
Step6_energies = read_en(Step6)[1]

fig, ax = plt.subplots(figsize=(60,30))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)



plt.hlines(Step1_energies[0],0,1,colors='black',linewidth=10)
plt.hlines(Step1_energies[1],2,3,colors='black',linewidth=10)
plt.hlines(Step1_energies[2],4,5,colors='black',linewidth=10)
    
plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='black',linewidth=10)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='black',linewidth=10)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='black',linewidth=10)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)

plt.hlines(Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)
plt.hlines(Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='black',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)

plt.hlines(Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='black',linewidth=10)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)

plt.hlines(Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)
plt.hlines(Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='black',linewidth=10)
plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='black',linewidth=10)




plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],c='black',linewidth=10)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],c='black',linewidth=10)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([13,14],[Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([15,16],[Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([17,18],[Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([21,22],[Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([23,24],[Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)







plt.hlines(Step1_energies[0],0,1,colors='limegreen',linewidth=10,alpha=0.5)
plt.hlines(Step1_energies[1],2,3,colors='limegreen',linewidth=10,alpha=0.5)
plt.hlines(Step1_energies[2],4,5,colors='limegreen',linewidth=10,alpha=0.5)

plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='limegreen',linewidth=10,alpha=0.5)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='limegreen',linewidth=10,alpha=0.5)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='limegreen',linewidth=10,alpha=0.5)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='limegreen',linewidth=10,alpha=0.5)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='limegreen',linewidth=10,alpha=0.5)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='limegreen',linewidth=10,alpha=0.5)

plt.hlines(2+Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='limegreen',linewidth=10)
plt.hlines(-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='limegreen',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='limegreen',linewidth=10,alpha=0.5)

plt.hlines(-5+Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='limegreen',linewidth=10)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='limegreen',linewidth=10,alpha=0.5)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='limegreen',linewidth=10,alpha=0.5)

plt.hlines(2+Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='limegreen',linewidth=10)
plt.hlines(-2+Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='limegreen',linewidth=10)
plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='limegreen',linewidth=10,alpha=0.5)




plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],c='limegreen',linewidth=10,alpha=0.5)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],c='limegreen',linewidth=10,alpha=0.5)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],c='limegreen',linewidth=10,alpha=0.5)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10,alpha=0.5)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10,alpha=0.5)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],2+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10)

plt.plot([13,14],[2+Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10)
plt.plot([15,16],[-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],-5+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10)

plt.plot([17,18],[-5+Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],2+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10,alpha=0.5)

plt.plot([21,22],[2+Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],-2+Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10)
plt.plot([23,24],[-2+Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='limegreen',linewidth=10)



plt.axis('off')
plt.tick_params(axis='both', left=False, top=False, right=False, bottom=False, labelleft=False, labeltop=False, labelright=False, labelbottom=False)
plt.savefig('EnergyPlot.png', dpi=300, bbox_inches='tight', pad_inches=0.0,transparent="True")

# %%
Step1_energies = read_en_e(Step1)[1]
Step2_energies = read_en_e(Step2)[1]
Step3_energies = read_en_e(Step3)[1]
Step4_energies = read_en_e(Step4)[1]
Step5_energies = read_en(Step5)[1]
Step6_energies = read_en(Step6)[1]

fig, ax = plt.subplots(figsize=(40,30))
ax.tick_params(axis="y",direction="in")
ax.tick_params(axis="x",direction="in")

plt.grid(axis='y', color='pink', linewidth=0.8)



plt.hlines(Step1_energies[0],0,1,colors='black',linewidth=3)
plt.hlines(Step1_energies[1],2,3,colors='black',linewidth=12)
plt.hlines(Step1_energies[2],4,5,colors='black',linewidth=3)
    
plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='black',linewidth=3)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='black',linewidth=12)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=3)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=3)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='black',linewidth=12)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=3)

plt.hlines(Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=3)
plt.hlines(Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='black',linewidth=12)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=3)

plt.hlines(Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=3)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='black',linewidth=12)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=3)

plt.hlines(Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=3)
plt.hlines(Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='black',linewidth=12)
plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='black',linewidth=3)

plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],c='black',linewidth=3)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],c='black',linewidth=3)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],c='black',linewidth=3)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)

plt.plot([13,14],[Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)
plt.plot([15,16],[Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)

plt.plot([17,18],[Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)

plt.plot([21,22],[Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)
plt.plot([23,24],[Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=3)


#plt.xticks([0.5,2.5,4.5,6.5,8.5,10.5,12.5,14.5,16.5,18.5,20.5,22.5,24.5],
  #         ['R','TS1','I1','TS2','I2','TS3','I3','TS4','I4','TS5','I5','TS6','P']
  #        ,fontsize=80,fontname='Arial')

plt.yticks(np.arange(-60, 20, 4),fontname='Arial')
plt.xticks([])
ax.tick_params(axis='both', which='major', labelsize=50, width=2.5, length=10,pad=30)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
#plt.ylabel('relative electronic energy (kcal/mol)',fontname='Arial',fontsize=80)
plt.xlim(0,25)
#plt.show()
plt.savefig('EnergyPlot.png', dpi=300, bbox_inches='tight', pad_inches=0.0,transparent="True")

# %%
### Energy Plot example enzyme

### Energy Plot without labels

Step1_energies = read_en_e(Step1)[1]
Step2_energies = read_en_e(Step2)[1]
Step3_energies = read_en_e(Step3)[1]
Step4_energies = read_en_e(Step4)[1]
Step5_energies = read_en(Step5)[1]
Step6_energies = read_en(Step6)[1]

fig, ax = plt.subplots(figsize=(60,30))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)



plt.hlines(Step1_energies[0],0,1,colors='black',linewidth=10)
plt.hlines(Step1_energies[1],2,3,colors='black',linewidth=10)
plt.hlines(Step1_energies[2],4,5,colors='black',linewidth=10)
    
plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='black',linewidth=10)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='black',linewidth=10)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='black',linewidth=10)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)

plt.hlines(Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)
plt.hlines(Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='black',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)

plt.hlines(Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='black',linewidth=10)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)

plt.hlines(Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='black',linewidth=10)
plt.hlines(Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='black',linewidth=10)
plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='black',linewidth=10)




plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],c='black',linewidth=10)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],c='black',linewidth=10)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([13,14],[Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([15,16],[Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([17,18],[Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([21,22],[Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([23,24],[Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)







plt.hlines(5+Step1_energies[0],0,1,colors='mediumorchid',linewidth=10)
plt.hlines(-5+Step1_energies[1],2,3,colors='mediumorchid',linewidth=10)
plt.hlines(1+Step1_energies[2],4,5,colors='mediumorchid',linewidth=10)

plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(6+Step2_energies[2]+Step1_energies[2],8,9,colors='mediumorchid',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(-2+Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='mediumorchid',linewidth=10,alpha=0.5)

plt.hlines(2+Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='mediumorchid',linewidth=10)
plt.hlines(-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='mediumorchid',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='mediumorchid',linewidth=10,alpha=0.5)

plt.hlines(-5+Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='mediumorchid',linewidth=10)
plt.hlines(Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],18,19,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='mediumorchid',linewidth=10,alpha=0.5)

plt.hlines(2+Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],20,21,colors='mediumorchid',linewidth=10)
plt.hlines(-2+Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],22,23,colors='mediumorchid',linewidth=10)
plt.hlines(Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],24,25,colors='mediumorchid',linewidth=10,alpha=0.5)




plt.plot([1,2],[5+Step1_energies[0],-5+Step1_energies[1]],c='mediumorchid',linewidth=10)
plt.plot([3,4],[-5+Step1_energies[1],1+Step1_energies[2]],c='mediumorchid',linewidth=10)

plt.plot([5,6],[1+Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],c='mediumorchid',linewidth=10)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],6+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10,alpha=0.5)

plt.plot([9,10],[6+Step3_energies[0]+Step2_energies[2]+Step1_energies[2],-2+Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)
plt.plot([11,12],[-2+Step3_energies[1]+Step2_energies[2]+Step1_energies[2],2+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)

plt.plot([13,14],[2+Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)
plt.plot([15,16],[-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],-5+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)

plt.plot([17,18],[-5+Step5_energies[0]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)
plt.plot([19,20],[Step5_energies[1]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],2+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10,alpha=0.5)

plt.plot([21,22],[2+Step6_energies[0]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],-2+Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)
plt.plot([23,24],[-2+Step6_energies[1]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step6_energies[2]+Step5_energies[2]+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)


#plt.grid(axis='y', color='red', linewidth=0.8)

#plt.axis('off')
plt.tick_params(axis='both', left=False, top=False, right=False, bottom=False, labelleft=False, labeltop=False, labelright=False, labelbottom=False)
plt.savefig('EnergyPlot1.png', dpi=300, bbox_inches='tight', pad_inches=0.0,transparent="True")

# %%
### Energy Plot example enzyme

### Energy Plot without labels

Step1_energies = read_en_e(Step1)[1]
Step2_energies = read_en_e(Step2)[1]
Step3_energies = read_en_e(Step3)[1]
Step4_energies = read_en_e(Step4)[1]


fig, ax = plt.subplots(figsize=(60,30))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)



plt.hlines(Step1_energies[0],0,1,colors='black',linewidth=10)
plt.hlines(Step1_energies[1],2,3,colors='black',linewidth=10)
plt.hlines(Step1_energies[2],4,5,colors='black',linewidth=10)
    
plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='black',linewidth=10)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='black',linewidth=10)
plt.hlines(Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='black',linewidth=10)
plt.hlines(Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='black',linewidth=10)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)

plt.hlines(Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='black',linewidth=10)
plt.hlines(Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='black',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='black',linewidth=10)





plt.plot([1,2],[Step1_energies[0],Step1_energies[1]],c='black',linewidth=10)
plt.plot([3,4],[Step1_energies[1],Step1_energies[2]],c='black',linewidth=10)

plt.plot([5,6],[Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([9,10],[Step3_energies[0]+Step2_energies[2]+Step1_energies[2],Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([11,12],[Step3_energies[1]+Step2_energies[2]+Step1_energies[2],Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)

plt.plot([13,14],[Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)
plt.plot([15,16],[Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='black',linewidth=10)






plt.hlines(5+Step1_energies[0],0,1,colors='mediumorchid',linewidth=10)
plt.hlines(-5+Step1_energies[1],2,3,colors='mediumorchid',linewidth=10)
plt.hlines(1+Step1_energies[2],4,5,colors='mediumorchid',linewidth=10)

plt.hlines(Step2_energies[0]+Step1_energies[2],4,5,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(Step2_energies[1]+Step1_energies[2],6,7,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(6+Step2_energies[2]+Step1_energies[2],8,9,colors='mediumorchid',linewidth=10)

plt.hlines(Step3_energies[0]+Step2_energies[2]+Step1_energies[2],8,9,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(-2+Step3_energies[1]+Step2_energies[2]+Step1_energies[2],10,11,colors='mediumorchid',linewidth=10,alpha=0.5)
plt.hlines(Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='mediumorchid',linewidth=10,alpha=0.5)

plt.hlines(2+Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],12,13,colors='mediumorchid',linewidth=10)
plt.hlines(-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],14,15,colors='mediumorchid',linewidth=10)
plt.hlines(Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],16,17,colors='mediumorchid',linewidth=10,alpha=0.5)





plt.plot([1,2],[5+Step1_energies[0],-5+Step1_energies[1]],c='mediumorchid',linewidth=10)
plt.plot([3,4],[-5+Step1_energies[1],1+Step1_energies[2]],c='mediumorchid',linewidth=10)

plt.plot([5,6],[1+Step2_energies[0]+Step1_energies[2],Step2_energies[1]+Step1_energies[2]],c='mediumorchid',linewidth=10)
plt.plot([7,8],[Step2_energies[1]+Step1_energies[2],6+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10,alpha=0.5)

plt.plot([9,10],[6+Step3_energies[0]+Step2_energies[2]+Step1_energies[2],-2+Step3_energies[1]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)
plt.plot([11,12],[-2+Step3_energies[1]+Step2_energies[2]+Step1_energies[2],2+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)

plt.plot([13,14],[2+Step4_energies[0]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)
plt.plot([15,16],[-2+Step4_energies[1]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2],-5+Step4_energies[2]+Step3_energies[2]+Step2_energies[2]+Step1_energies[2]],c='mediumorchid',linewidth=10)




#plt.grid(axis='y', color='red', linewidth=0.8)

#plt.axis('off')
plt.tick_params(axis='both', left=False, top=False, right=False, bottom=False, labelleft=False, labeltop=False, labelright=False, labelbottom=False)
plt.savefig('EnergyPlot1.png', dpi=300, bbox_inches='tight', pad_inches=0.0,transparent="True")
